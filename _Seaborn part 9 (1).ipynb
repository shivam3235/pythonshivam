# %% [markdown]
# # Seaborn Color Paletters part 9

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips =sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Basics and Custom Paletters

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",data=tips)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 sns.scatterplot(x="total_bill",y="tip",hue="day",data=tips)
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # import matplotlib libary then Error the excuted

# %%
sns.scatterplot(x="total_bill",y="tip",hue="day",data=tips)
()plt.show

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x="total_bill",y="tip",hue="day",data=tips)
plt.show()

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,color="r")
plt.show()

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,color="g")
plt.show()
